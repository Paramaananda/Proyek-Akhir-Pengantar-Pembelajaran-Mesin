# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0   55         165          60       81.0             0.5
# 1   1   70         165          65       89.0             0.6
# 2   2   20         170          75       81.0             0.4
# 3   3   35         180          95      105.0             1.5
# 4   4   30         165          60       80.5             1.5
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  LDL  \
# 0              0.6              1               1       135  ...   40   75
# 1              0.7              2               2       146  ...   57  126
# 2              0.5              1               1       118  ...   45   93
# 3              1.2              1               1       131  ...   38  102
# 4              1.0              1               1       121  ...   44   93
#
#    hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# ...

# %%
df = df.drop(columns=["id","height(cm)","hearing(left)","hearing(right)","Urine protein","ALT",])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159256 entries, 0 to 159255
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   age                  159256 non-null  int64
#  1   weight(kg)           159256 non-null  int64
#  2   waist(cm)            159256 non-null  float64
#  3   eyesight(left)       159256 non-null  float64
#  4   eyesight(right)      159256 non-null  float64
#  5   systolic             159256 non-null  int64
#  6   relaxation           159256 non-null  int64
#  7   fasting blood sugar  159256 non-null  int64
#  8   Cholesterol          159256 non-null  int64
#  9   triglyceride         159256 non-null  int64
#  10  HDL                  159256 non-null  int64
#  11  LDL                  159256 non-null  int64
#  12  hemoglobin           159256 non-null  float64
#  13  serum creatinine     159256 non-null  float64
#  14  AST                  159256 non-null  int64
# ...

# %%
knn_model = KNeighborsClassifier(n_neighbors=3)

# %%
svm_model = SVC()

# %%
x = df[df.columns[:-1]]
y = df[df.columns[-1]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
hasil_knn = knn_model.predict(x_test)

# %%
hasil_svm = svm_model.predict(x_test)

# %%
hasil_rf = rf_model.predict(x_test)

# %%
print("akurasi knn:")
print(accuracy_score(y_test,hasil_knn))
# Out:
# akurasi knn:
# 0.6876491272133618

# %%
print("akurasi svm:")
print(accuracy_score(y_test,hasil_svm))
# Out:
# akurasi svm:
# 0.7444744443049102

# %%
print("akurasi random forest:")
print(accuracy_score(y_test,hasil_rf))
# Out:
# akurasi random forest:
# 0.7640650508602286

# %%
data_test = pd.read_csv("test.csv")

# %%
id = data_test["id"]
data_test = data_test.drop(columns=["id","height(cm)","hearing(left)","hearing(right)","Urine protein","ALT",])

# %%
hasil = svm_model.predict(data_test)

# %%
hasil = pd.Series(hasil)

# %%
hasil = pd.concat([id,hasil],axis=1)

# %%
hasil.head()
# Out:
#        id  0
# 0  159256  1
# 1  159257  0
# 2  159258  1
# 3  159259  0
# 4  159260  1

# %%
hasil.rename(columns={0:"smoking"},inplace=True)

# %%
hasil.head()
# Out:
#        id  smoking
# 0  159256        1
# 1  159257        0
# 2  159258        1
# 3  159259        0
# 4  159260        1

# %%
hasil.to_csv("hasil.csv",index=False)
